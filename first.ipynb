# %%
# DATA VISUALIZATION , ADVANCE OF MATPLOTLIB
# pip insatll seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Visualize Distributions With Seaborn
#
# As a python library which is used for create a graph
# that is best library for create the graph
#
# Seaborn is a library that uses Matplotlib underneath to plot graphs.
#
# It will be used to visualize random distributions.
#
# various types of graph in seaborn
# Relational Plots:
#
# 1. scatterplot()
# 2. lineplot()
#
#
# Categorical Plots:
#
# 1. stripplot()
# 2. swarmplot()
# 3. boxplot()
# 4. violinplot()
# 5. boxenplot()
# 6. pointplot()
# 7. barplot()
# 8. countplot()
#
#
# Distribution Plots:
#
# 1. histplot()
# 2. kdeplot()
# 3. ecdfplot()
# 4. rugplot()
#
# Matrix Plots:
#
# 1. heatmap()
# 2. clustermap()
#
# Regression Plots:
#
# 1. lmplot()
# 2. regplot()
# 3. residplot()

# %%
# alredy provide data
data =sns.load_dataset("tips") # load dataset fron seaborn
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.head() # default top 5 rows
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.tail() # default lst 5 rows
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
data.info()  # information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
data.describe() #numerical data info
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
plt.plot(data['total_bill']) # plt a feature

# %%
plt.plot(data['tip'])

# %% [markdown]
# # Line plot

# %%
sns.lineplot(data['total_bill']) #plot a feature
# lineplot of totalbill
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# # Scatter plot

# %%
sns.scatterplot(x ='total_bill',y ='tip',data=data) #scatter plot of totalbill and tips
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Hist plot

# %%
sns.histplot(data['total_bill']) # histogram
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
plt.hist(data['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Kdeplot

# %%
sns.kdeplot(data['total_bill']) #kdeplot of totalbill
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# 1. catplot graph : catgroial data
# 2. relay plot : relation
# 3. scatter plot

# %% [markdown]
#  # Relay plot

# %%
sns.relplot(x='total_bill',y='tip',data=data) #scatter plot of tip nd bill

# %%
data['time'].unique() #unique value
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
sns.relplot(x='total_bill',y='tip',hue='time',data=data)    #viewing the no of customer visiting in lunch and dinner
# used to display comaprison

# %%
sns.relplot(x='total_bill',y='tip',hue='time',style='smoker',data=data)  # used to differntiate btw smoker or non smoker

# %%
# differnt graph of smoker
sns.relplot(x='total_bill',y='tip',hue='time',style='smoker',kind='scatter',col='smoker',data=data)  # kind for multiple graph , col for the reason

# %%
# differnt graph of time
sns.relplot(x='total_bill',y='tip',hue='time',style='smoker',kind='scatter',col='time',data=data)

# %%
sns.relplot(x='total_bill',y='tip',hue='time',style='smoker',kind='scatter',row='time',data=data) #row for row representaion

# %%
data['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.relplot(x='total_bill',y='tip',hue='time',style='smoker',kind='scatter',col='day',data=data) # for multiple graph acc tO features unique value

# %%
# xlabel ,ylabel,tile
sns.relplot(x='total_bill',y='tip',data=data)
plt.title('total_bill vs tip')
plt.xlabel("total_bill",fontsize=20,color='purple')
plt.ylabel('tip',fontsize=20,color='indigo')
# Out:
# Text(13.819444444444445, 0.5, 'tip')

# %% [markdown]
# # Cat plot

# %%
sns.catplot(x='day',y='total_bill',data=data,kind='swarm') # display catplot and swarn to disply horizontal data

# %%
sns.catplot(x='day',y='total_bill',data=data,kind='strip') # strip to display dataset

# %%
sns.catplot(x='day',y='total_bill',data=data,kind='box')   #represnt the maximum range of the day

# %%
sns.catplot(x='day',y='total_bill',data=data,kind='bar')  # display the max range

# %%
sns.catplot(x='day',y='total_bill',data=data,kind='violin')  # display the max range

# %%
sns.catplot(x='day',y='total_bill',data=data,kind='boxen') # display the max range

# %% [markdown]
# # Count plot

# %%
plt.Figure(figsize=(5,5))
sns.countplot(data['day']) # count the value of costumers
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
plt.Figure(figsize=(5,5))
sns.countplot(data['time']) # count the  value of customer
# Out:
# <Axes: xlabel='count', ylabel='time'>

# %%
sns.boxplot(data['total_bill']) # display highest customer range
# Out:
# <Axes: ylabel='total_bill'>
